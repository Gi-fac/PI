# %% [markdown]
# # Exercício 1
#
# Crie um programa que recebe 3 números positivos digitados pelo usuário. O programa deve determinar se os três números formam um triângulo retângulo. Por exemplo, $3$, $4$ e $5$ formam um triângulo retângulo pois $3^2 + 4^2 = 5^2$. Nota: os números podem ser digitados em qualquer ordem (por exemplo, você não pode presumir que o usuário digite os valores em ordem crescente).

# %%
# resolva o exercício 1 nesta célula

# %% [markdown]
# # Exercício 2
#
# Em uma certo um país, o imposto de renda devido é calculado de maneira progressiva, de acordo com a regra abaixo:
# - até 500 dinheiros, a alíquota é zero (isenção).
# - acima de 500 até 1000 dinheiros, o imposto é calculado como:
# Imposto = (Renda - 500)*0.1
# - acima de 1000 dinheiros, o imposto é calculado como:
# Imposto = 50 + (Renda - 1000)*0.2.
#
# A alíquota efetiva do imposto é dada pela razão (Imposto)/(Renda). Faça um programa que recebe um valor de renda digitado pelo usuário (expresso por um número em ponto flutuante) e imprime o valor do imposto devido e da alíquota efetiva.

# %%
# resolva o exercício 2 nesta célula

# %% [markdown]
# # Exercício 3
#
# Faça um programa que recebe um número inteiro $n$ , $1 \leq n \leq 100$ e imprime sua representação em numerais romanos. Lembre-se que você pode criar _strings_ (cadeias de caracteres) iterativamente usando o operador de _concatenação_ (+). Veja o código abaixo:

# %%
s = "" # string vazio
s = s + "C"
print(s)
s = s + "XL" # agora o conteúdo de s é "CXL"
print(s)
